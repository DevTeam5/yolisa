# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing pandas as pd 
import pandas as pd 

df = pd.read_csv("PandasSprint1") 
df
# Out:
#                  Items Price  Quantinty  Sizes  Calories
# 0               CHIPS:   NaN        NaN    NaN       NaN
# 1                 Lays   R12       80.0    28g     120.0
# 2               Fritos    R4      100.0    25g     160.0
# 3                Simba   R12       50.0    36g     190.0
# 4             NickNaks    R1      100.0   200g     307.0
# 5           Ghost Pops    R8       30.0    20g     163.0
# 6          COOLDRINKS:   NaN        NaN    NaN       NaN
# 7                 Coke    R8       20.0  375ml     140.0
# 8                Fanta    R7       10.0  375ml     110.0
# 9               Stoney    R8       20.0  375ml     191.0
# 10              Sprite    R8       20.0  375ml     158.0
# 11          Spar Letta    R7       10.0  375ml     150.0
# 12         CHOCOLATES:   NaN        NaN    NaN       NaN
# 13             Kit Kat   R20       30.0    45g     230.0
# 14  Cudbury dairy milk   R16       20.0    80g     134.0
# ...

# %%
df['Sum Item'] = df.sum(axis=1)
df.loc['Sum Snacks '] = df.sum()
df
# Out:
#                                                          Items Price  \
# 0                                                       CHIPS:   NaN
# 1                                                         Lays   R12
# 2                                                       Fritos    R4
# 3                                                        Simba   R12
# 4                                                     NickNaks    R1
# 5                                                   Ghost Pops    R8
# 6                                                  COOLDRINKS:   NaN
# 7                                                         Coke    R8
# 8                                                        Fanta    R7
# 9                                                       Stoney    R8
# 10                                                      Sprite    R8
# 11                                                  Spar Letta    R7
# 12                                                 CHOCOLATES:   NaN
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

#line plotting 
x = [12, 11, 37, 13, 73]
y = [4.0, 7.0, 16.0, 15.0, 42.0]
plt.plot(x,y,x,y)

plt.xlabel('Chips', fontsize = 15)
plt.ylabel('Cooldrinks', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
# Data
df=pd.DataFrame({'x': range(12, 11, 37, 13, 73), 'y1': np.random.randn(10), 'y2': np.random.randn(10)+range(4.0, 7.0, 16.0, 15.0, 42.0)}) 
 
# multiple line plot
plt.plot( 'x', 'y1', data=df, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
x = [12,4,12,1,8] #prices
y =[120,160,190,307,163] #calories
plt.scatter(x,y, color = 'r',s = 100)
plt.grid()

# %%
import matplotlib.pyplot as plt
import pandas as pd

y = [12, 4, 12, 1, 11, 7, 12, 8, 7, 37, 16, 30, 38,13, 15, 18, 23]

# Creating a histogram
plt.hist(y)
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

data = {'kitkat': 10, 'Cudbury': 15, 'Ps': 5, 'Lunchbar': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Chocolates')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

data = {'Chips': 109438.50,
        'Cooldrinks': 103569.59,
        'Chocolates': 112214.71,
        'Pies': 112591.43,
        'Fruits': 100934.30,
        'Vegetables': 103660.54,
        'Cupcakes': 137351.96}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 7 artists>
